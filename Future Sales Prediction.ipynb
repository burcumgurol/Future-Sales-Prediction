# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv("https://raw.githubusercontent.com/amankharwal/Website-data/master/advertising.csv")
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
print(data.isnull().sum())
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
import plotly.express as px
fig = px.scatter(data,x = "Sales",y = "TV",size = "TV",color = 'Sales',trendline = "ols")
fig.show()

# %%
import plotly.express as px
fig = px.scatter(data,x = "Sales",y = "Radio",size = "Radio",color = 'Sales',trendline = "ols")
fig.show()

# %%
import plotly.express as px
fig = px.scatter(data,x = "Sales",y = "Newspaper",size = "Newspaper",color = 'Sales',trendline = "ols")
fig.show()

# %%
correlation = data.corr()
correlation["Sales"]
# Out:
# TV           0.901208
# Radio        0.349631
# Newspaper    0.157960
# Sales        1.000000
# Name: Sales, dtype: float64

# %%
x = np.array(data.drop(["Sales"],axis = 1))
y = np.array(data["Sales"])

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state = 42)
regression = LinearRegression().fit(x,y)
regression.score(x,y)
# Out:
# 0.9025912899684558

# %%
features = np.array([[225.3,41,23]])
print(regression.predict(features))
# Out:
# [21.28652888]
